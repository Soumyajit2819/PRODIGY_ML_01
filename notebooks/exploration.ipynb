# %% [markdown]
# # House Price Prediction — Exploratory Notebook
#
# This notebook is for **experimentation only**.
# The production implementation is in the Python scripts (`main.py`, `preprocess.py`, `train.py`, etc.).

# %%
import sys
sys.path.insert(0, '..')   # allow importing project modules

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.rcParams['figure.figsize'] = (12, 5)

# %%
df = pd.read_csv('../data/train.csv')
print(df.shape)
df.head()

# %%
df.describe()

# %%
# Missing value analysis
missing = df.isnull().sum().sort_values(ascending=False)
missing[missing > 0]

# %%
# SalePrice distribution
fig, axes = plt.subplots(1, 2)
df['SalePrice'].hist(ax=axes[0], bins=40)
axes[0].set_title('SalePrice')
np.log1p(df['SalePrice']).hist(ax=axes[1], bins=40)
axes[1].set_title('log(SalePrice)')
plt.tight_layout()
